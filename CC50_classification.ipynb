# %% [markdown]
# Классификация для CC50.

# %%
model_kneighb_cc = KNeighborsClassifier()

model_kneighb_cc.fit(X_train_class_cc, y_train_class_cc)
pred_ic_kneighb_cc = model_kneighb_cc.predict(X_test_class_cc)

accuracy_kneighb_cc = accuracy_score(y_test_class_cc, pred_ic_kneighb_cc)
print(f'Accuracy: {accuracy_kneighb_cc}')
# Out:
# Accuracy: 0.717607973421927

# %%
model_for_cc_class = RandomForestClassifier()

model_for_cc_class.fit(X_train_class_cc, y_train_class_cc)
pred_ic_for_cc_class = model_for_cc_class.predict(X_test_class_cc)

accuracy_for_cc_class = accuracy_score(y_test_class_cc, pred_ic_for_cc_class)
print(f'Accuracy: {accuracy_for_cc_class}')
# Out:
# Accuracy: 0.7408637873754153

# %%
model_lg_cc = LogisticRegression()

model_lg_cc.fit(X_train_class_cc, y_train_class_cc)
pred_ic_lg_cc = model_lg_cc.predict(X_test_class_cc)

accuracy_lg_cc = accuracy_score(y_test_class_cc, pred_ic_lg_cc)
print(f'Accuracy: {accuracy_lg_cc}')
# Out:
# Accuracy: 0.7109634551495017

# %% [markdown]
# Наиболее эффективно CC50 > медианы классифицирует алгоритм случайного леса.

# %%
param_dist_cc_class = {
    'n_estimators': randint(50, 300),
    'max_depth': randint(3, 10),
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(1, 10)
}

random_search_cc_class = RandomizedSearchCV(
    estimator=RandomForestClassifier(),
    param_distributions=param_dist_cc_class,
    n_iter=50,       # сколько комбинаций попробовать
    cv=5,
    scoring='r2',
    n_jobs=-1,
    random_state=42
)

random_search_cc_class.fit(X_train_class_cc, y_train_class_cc)

print("Лучшие параметры:", random_search_cc_class.best_params_)
# Out:
# Лучшие параметры: {'max_depth': 9, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 290}

# %%
forest_for_cc_class = RandomForestClassifier(
    n_estimators = random_search_cc_class.best_params_['n_estimators'],
    max_depth = random_search_cc_class.best_params_['max_depth'],
    min_samples_split = random_search_cc_class.best_params_['min_samples_split'],
    min_samples_leaf = random_search_cc_class.best_params_['min_samples_leaf'],
    random_state=42
)
forest_for_cc_class.fit(X_train_class_cc, y_train_class_cc)
# Out:
# RandomForestClassifier(max_depth=9, min_samples_leaf=3, min_samples_split=8,
#                        n_estimators=290, random_state=42)

# %%
forest_test_for_cc_class = forest_for_cc_class.predict(X_test_class_cc)  

ac_test_forest_for_cc_class = accuracy_score(y_test_class_cc, forest_test_for_cc_class)
f1_test_forest_for_cc_class = f1_score(y_test_class_cc, forest_test_for_cc_class)
prec_test_forest_for_cc_class = precision_score(y_test_class_cc, forest_test_for_cc_class)
rec_test_forest_for_cc_class = recall_score(y_test_class_cc, forest_test_for_cc_class)

print("Accuracy на тесте:", ac_test_forest_for_cc_class)
print("F1 на тесте:", f1_test_forest_for_cc_class)
print("Precision:", prec_test_forest_for_cc_class)
print("Recall:", rec_test_forest_for_cc_class)
# Out:
# Accuracy на тесте: 0.760797342192691
# F1 на тесте: 0.7721518987341772
# Precision: 0.7672955974842768
# Recall: 0.7770700636942676
