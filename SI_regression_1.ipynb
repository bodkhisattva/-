# %% [markdown]
# Регрессия для SI.

# %%
model_forest_si = RandomForestRegressor()

model_forest_si.fit(X_train_si, y_train_si)
pred_forest_si = model_forest_si.predict(X_test_si)

scores_forest_si = cross_val_score(model_forest_si, X_train_si, y_train_si, cv=5, scoring='r2')
print("Среднее R2:", scores_forest_si.mean())
# Out:
# Среднее R2: 0.20202070887127474

# %%
r2_test_for_si = r2_score(y_test_si, pred_forest_si)
print("R2 на тесте:", r2_test_for_si)
# Out:
# R2 на тесте: 0.2428623536161253

# %%
model_grad_si = GradientBoostingRegressor()

model_grad_si.fit(X_train_si, y_train_si)
pred_grad_si = model_grad_si.predict(X_test_si)

scores_grad_si = cross_val_score(model_grad_si, X_train_si, y_train_si, cv=5, scoring='r2')
print("Среднее R2:", scores_grad_si.mean())
# Out:
# Среднее R2: 0.20036833474538743

# %%
r2_test_grad_si = r2_score(y_test_si, pred_grad_si)
print("R2 на тесте:", r2_test_grad_si)
# Out:
# R2 на тесте: 0.21825227566272953

# %%
model_linear_si = LinearRegression()

model_linear_si.fit(X_train_si, y_train_si)
pred_linear_si = model_linear_si.predict(X_test_si)

scores_linear_si = cross_val_score(model_linear_si, X_train_si, y_train_si, cv=5, scoring='r2')
print("Среднее R2:", scores_linear_si.mean())
# Out:
# Среднее R2: 0.05423109186390074

# %%
r2_test_lin_si = r2_score(y_test_si, pred_linear_si)
print("R2 на тесте:", r2_test_lin_si)
# Out:
# R2 на тесте: 0.09673395834064791

# %%
model_xg_si = XGBRegressor(n_estimators=1000, max_depth=7, eta=0.1, subsample=0.7, colsample_bytree=0.8)

model_xg_si.fit(X_train_si, y_train_si)
pred_xg_si = model_xg_si.predict(X_test_si)

scores_xg_si = cross_val_score(model_xg_si, X_train_si, y_train_si, cv=5, scoring='r2')
print("Среднее R2:", scores_xg_si.mean())
# Out:
# Среднее R2: 0.1320579167465699

# %% [markdown]
# Для регрессии SI также выбираем алгоритм случайного леса.

# %%
param_dist_si = {
    'n_estimators': randint(50, 300),
    'max_depth': randint(3, 10),
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(1, 10)
}

random_search_si = RandomizedSearchCV(
    estimator=RandomForestRegressor(),
    param_distributions=param_dist_si,
    n_iter=50,       # сколько комбинаций попробовать
    cv=5,
    scoring='r2',
    n_jobs=-1,
    random_state=42
)

random_search_si.fit(X_train_si, y_train_si)

print("Лучшие параметры:", random_search_si.best_params_)
# Out:
# Лучшие параметры: {'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 97}

# %%
forest_for_si = RandomForestRegressor(
    n_estimators = random_search_si.best_params_['n_estimators'],
    max_depth = random_search_si.best_params_['max_depth'],
    min_samples_split = random_search_si.best_params_['min_samples_split'],
    min_samples_leaf = random_search_si.best_params_['min_samples_leaf'],
    random_state=42
)
forest_for_si.fit(X_train_si, y_train_si)
# Out:
# RandomForestRegressor(max_depth=6, min_samples_leaf=2, n_estimators=97,
#                       random_state=42)

# %%
forest_for_si_test = forest_for_si.predict(X_test_si)

r2_test_forest_for_si = r2_score(y_test_si, forest_for_si_test)
print("R2 на тесте:", r2_test_forest_for_si)
# Out:
# R2 на тесте: 0.25915523203691504
