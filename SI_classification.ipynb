# %% [markdown]
# Классификация для SI.

# %%
model_kneighb_si = KNeighborsClassifier()

model_kneighb_si.fit(X_train_class_si, y_train_class_si)
pred_ic_kneighb_si = model_kneighb_si.predict(X_test_class_si)

accuracy_kneighb_si = accuracy_score(y_test_class_si, pred_ic_kneighb_si)
print(f'Accuracy: {accuracy_kneighb_si}')
# Out:
# Accuracy: 0.6345514950166113

# %%
model_for_si_class = RandomForestClassifier()

model_for_si_class.fit(X_train_class_si, y_train_class_si)
pred_ic_for_si = model_for_si_class.predict(X_test_class_si)

accuracy_for_si_class = accuracy_score(y_test_class_si, pred_ic_for_si)
print(f'Accuracy: {accuracy_for_si_class}')
# Out:
# Accuracy: 0.6511627906976745

# %%
model_lg_si = LogisticRegression()

model_lg_si.fit(X_train_class_si, y_train_class_si)
pred_ic_lg_si = model_lg_si.predict(X_test_class_si)

accuracy_lg_si = accuracy_score(y_test_class_si, pred_ic_lg_si)
print(f'Accuracy: {accuracy_lg_si}')
# Out:
# Accuracy: 0.6146179401993356

# %% [markdown]
# Наиболее эффективно SI > медианы классифицирует алгоритм случайного леса.

# %%
param_dist_si_class = {
    'n_estimators': randint(50, 300),
    'max_depth': randint(3, 10),
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(1, 10)
}

random_search_si_class = RandomizedSearchCV(
    estimator=RandomForestClassifier(),
    param_distributions=param_dist_si_class,
    n_iter=50,       # сколько комбинаций попробовать
    cv=5,
    scoring='r2',
    n_jobs=-1,
    random_state=42
)

random_search_si_class.fit(X_train_class_si, y_train_class_si)

print("Лучшие параметры:", random_search_si_class.best_params_)
# Out:
# Лучшие параметры: {'max_depth': 9, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 290}

# %%
forest_for_si_class = RandomForestClassifier(
    n_estimators = random_search_si_class.best_params_['n_estimators'],
    max_depth = random_search_si_class.best_params_['max_depth'],
    min_samples_split = random_search_si_class.best_params_['min_samples_split'],
    min_samples_leaf = random_search_si_class.best_params_['min_samples_leaf'],
    random_state=42
)
forest_for_si_class.fit(X_train_class_si, y_train_class_si)
# Out:
# RandomForestClassifier(max_depth=9, min_samples_leaf=3, min_samples_split=8,
#                        n_estimators=290, random_state=42)

# %%
forest_test_for_si_class = forest_for_si_class.predict(X_test_class_si)  

ac_test_forest_for_si_class = accuracy_score(y_test_class_si, forest_test_for_si_class)
f1_test_forest_for_si_class = f1_score(y_test_class_si, forest_test_for_si_class)
prec_test_forest_for_si_class = precision_score(y_test_class_si, forest_test_for_si_class)
rec_test_forest_for_si_class = recall_score(y_test_class_si, forest_test_for_si_class)

print("Accuracy на тесте:", ac_test_forest_for_si_class)
print("F1 на тесте:", f1_test_forest_for_si_class)
print("Precision:", prec_test_forest_for_si_class)
print("Recall на тесте:", rec_test_forest_for_si_class)
# Out:
# Accuracy на тесте: 0.6578073089700996
# F1 на тесте: 0.6199261992619927
# Precision: 0.7
# Recall на тесте: 0.5562913907284768
