# %% [markdown]
# Классификация для SI > 8.

# %%
model_kneighb_si8 = KNeighborsClassifier()

model_kneighb_si8.fit(X_train_class_si8, y_train_class_si8)
pred_si_kneighb_si8 = model_kneighb_si8.predict(X_test_class_si8)

accuracy_kneighb_si8 = accuracy_score(y_test_class_si8, pred_si_kneighb_si8)
print(f'Accuracy: {accuracy_kneighb_si8}')
# Out:
# Accuracy: 0.9501661129568106

# %%
model_for_si8 = RandomForestClassifier()

model_for_si8.fit(X_train_class_si8, y_train_class_si8)
pred_si_for_si8 = model_for_si8.predict(X_test_class_si8)

accuracy_for_si8 = accuracy_score(y_test_class_si8, pred_si_for_si8)
print(f'Accuracy: {accuracy_for_si8}')
# Out:
# Accuracy: 0.9401993355481728

# %% [markdown]
# Наиболее эффективно SI > 8 классифицирует алгоритм K ближайших соседей.

# %%
param_dist_si8_class = {
    'n_estimators': randint(50, 300),
    'max_depth': randint(3, 10),
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(1, 10)
}

random_search_si8_class = RandomizedSearchCV(
    estimator=RandomForestClassifier(class_weight='balanced'),
    param_distributions=param_dist_si8_class,
    n_iter=50,       # сколько комбинаций попробовать
    cv=5,
    scoring='r2',
    n_jobs=-1,
    random_state=42
)

random_search_si8_class.fit(X_train_class_si8, y_train_class_si8)

print("Лучшие параметры:", random_search_si8_class.best_params_)
# Out:
# Лучшие параметры: {'max_depth': 8, 'min_samples_leaf': 2, 'min_samples_split': 13, 'n_estimators': 211}

# %%
forest_for_si8_class = RandomForestClassifier(
    n_estimators = random_search_si8_class.best_params_['n_estimators'],
    max_depth = random_search_si8_class.best_params_['max_depth'],
    min_samples_split = random_search_si8_class.best_params_['min_samples_split'],
    min_samples_leaf = random_search_si8_class.best_params_['min_samples_leaf'],
    random_state=42
)
forest_for_si8_class.fit(X_train_class_si8, y_train_class_si8)
# Out:
# RandomForestClassifier(max_depth=8, min_samples_leaf=2, min_samples_split=13,
#                        n_estimators=211, random_state=42)

# %%
forest_test_for_si8_class = forest_for_si8_class.predict(X_test_class_si8)  

ac_test_forest_for_si8_class = accuracy_score(y_test_class_si8, forest_test_for_si8_class)
f1_test_forest_for_si8_class = f1_score(y_test_class_si8, forest_test_for_si8_class, zero_division = 0)
prec_test_forest_for_si8_class = precision_score(y_test_class_si8, forest_test_for_si8_class, zero_division = 0)
rec_test_forest_for_si8_class = recall_score(y_test_class_si8, forest_test_for_si8_class, zero_division = 0)

print("Accuracy на тесте:", ac_test_forest_for_si8_class)
print("F1 на тесте:", f1_test_forest_for_si8_class)
print("Precision:", prec_test_forest_for_si8_class)
print("Recall на тесте:", rec_test_forest_for_si8_class)
# Out:
# Accuracy на тесте: 0.9534883720930233
# F1 на тесте: 0.9761092150170648
# Precision: 0.959731543624161
# Recall на тесте: 0.9930555555555556
